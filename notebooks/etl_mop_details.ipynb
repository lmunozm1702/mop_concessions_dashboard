# %%
import pandas as pd
import json
import regex as re
from unidecode import unidecode


def print_null_count(df):
    null_count = df.isnull().sum()
    print(null_count[null_count > 0])

# %% [markdown]
# # ETL for mop_details_spider.json file

# %% [markdown]
# ## 1. Importing the data

# %%
with open("../mopscrapper/mop_details_spider.json", "r") as f:
    data = json.load(f)

df = pd.DataFrame(data)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   id                                       129 non-null    object
#  1   status                                   129 non-null    object
#  2   url                                      129 non-null    object
#  3   Tipo Iniciativa                          38 non-null     object
#  4   Región                                   129 non-null    object
#  5   Provincia                                129 non-null    object
#  6   Comuna                                   129 non-null    object
#  7   Volumen                                  129 non-null    object
#  8   Presupuesto Oficial                      98 non-null     object
#  9   *Valor de referencia                     38 non-null     object
#  10  Llamado a Licitación                     38 non-null     object
#  11  Fecha de Recepción de Ofertas Técnicas   129 non-null    object
#  12  Fecha de Apertura de Ofertas Económicas  98 non-null     object
#  13  Decreto de Adjudicación                  129 non-null    object
#  14  Sociedad Concesionaria                   129 non-null    object
#  15  Fecha de Inicio Concesión                38 non-null     object
#  16  Plazo Total de la Concesión              69 non-null     object
#  17  Puesta en Servicio Provisoria (PSP)      38 non-null     object
#  18  Inspector (a) Fiscal                     89 non-null     object
#  19  Tipo de Iniciativa                       91 non-null     object
#  20  Presupuesto oficial                      31 non-null     object
#  21  *Valor de Referencia                     91 non-null     object
#  22  Fecha de Llamado a Licitación            91 non-null     object
#  23  Fecha de Apertura Oferta Económica       31 non-null     object
#  24  Inicio Plazo Concesión                   91 non-null     object
#  25  Plazo de Concesión                       60 non-null     object
# dtypes: object(26)
# memory usage: 26.3+ KB

# %% [markdown]
# ## 2. Cleaning the data

# %% [markdown]
# ### 2.1. Handling missing values

# %%
print_null_count(df)
# Out:
# Tipo Iniciativa                            91
# Presupuesto Oficial                        31
# *Valor de referencia                       91
# Llamado a Licitación                       91
# Fecha de Apertura de Ofertas Económicas    31
# Fecha de Inicio Concesión                  91
# Plazo Total de la Concesión                60
# Puesta en Servicio Provisoria (PSP)        91
# Inspector (a) Fiscal                       40
# Tipo de Iniciativa                         38
# Presupuesto oficial                        98
# *Valor de Referencia                       38
# Fecha de Llamado a Licitación              38
# Fecha de Apertura Oferta Económica         98
# Inicio Plazo Concesión                     38
# Plazo de Concesión                         69
# dtype: int64

# %% [markdown]
# #### "Tipo Iniciativa" and "Tipo de Iniciativa" columns are equivalent and comlmenetary, we will merge them and drop "Tipo de Iniciativa" column.

# %%
df["Tipo Iniciativa"] = df["Tipo Iniciativa"].fillna(df["Tipo de Iniciativa"])
df.drop("Tipo de Iniciativa", axis=1, inplace=True)

print_null_count(df)
# Out:
# Presupuesto Oficial                        31
# *Valor de referencia                       91
# Llamado a Licitación                       91
# Fecha de Apertura de Ofertas Económicas    31
# Fecha de Inicio Concesión                  91
# Plazo Total de la Concesión                60
# Puesta en Servicio Provisoria (PSP)        91
# Inspector (a) Fiscal                       40
# Presupuesto oficial                        98
# *Valor de Referencia                       38
# Fecha de Llamado a Licitación              38
# Fecha de Apertura Oferta Económica         98
# Inicio Plazo Concesión                     38
# Plazo de Concesión                         69
# dtype: int64

# %% [markdown]
# #### "Presupuesto Oficial" and "Presupuesto Oficial" columns are equivalent and complmenetary, we will merge them and drop "Presupuesto Oficial" column.

# %%
df["Presupuesto Oficial"] = df["Presupuesto Oficial"].fillna(df["Presupuesto oficial"])
df.drop("Presupuesto oficial", axis=1, inplace=True)

print_null_count(df)
# Out:
# *Valor de referencia                       91
# Llamado a Licitación                       91
# Fecha de Apertura de Ofertas Económicas    31
# Fecha de Inicio Concesión                  91
# Plazo Total de la Concesión                60
# Puesta en Servicio Provisoria (PSP)        91
# Inspector (a) Fiscal                       40
# *Valor de Referencia                       38
# Fecha de Llamado a Licitación              38
# Fecha de Apertura Oferta Económica         98
# Inicio Plazo Concesión                     38
# Plazo de Concesión                         69
# dtype: int64

# %% [markdown]
# #### Columns "*Valor de referencia" and "*Valor de Referencia" are equivalent and complmenetary, we will merge them and drop "*Valor de Referencia" column.

# %% [markdown]
# ####

# %%
df["*Valor de referencia"] = df["*Valor de referencia"].fillna(
    df["*Valor de Referencia"]
)
df.drop("*Valor de Referencia", axis=1, inplace=True)

print_null_count(df)
# Out:
# Llamado a Licitación                       91
# Fecha de Apertura de Ofertas Económicas    31
# Fecha de Inicio Concesión                  91
# Plazo Total de la Concesión                60
# Puesta en Servicio Provisoria (PSP)        91
# Inspector (a) Fiscal                       40
# Fecha de Llamado a Licitación              38
# Fecha de Apertura Oferta Económica         98
# Inicio Plazo Concesión                     38
# Plazo de Concesión                         69
# dtype: int64

# %% [markdown]
# #### Columns "Llamado a Licitación" and "Fecha de Llamado a Licitación" are equivalent and complmenetary, we will merge them and drop "Fecha de Llamado a Licitación" column.

# %%
df["Llamado a Licitación"] = df["Llamado a Licitación"].fillna(
    df["Fecha de Llamado a Licitación"]
)
df.drop("Fecha de Llamado a Licitación", axis=1, inplace=True)

print_null_count(df)
# Out:
# Fecha de Apertura de Ofertas Económicas    31
# Fecha de Inicio Concesión                  91
# Plazo Total de la Concesión                60
# Puesta en Servicio Provisoria (PSP)        91
# Inspector (a) Fiscal                       40
# Fecha de Apertura Oferta Económica         98
# Inicio Plazo Concesión                     38
# Plazo de Concesión                         69
# dtype: int64

# %% [markdown]
# #### Columns "Fecha de Apertura de Ofertas Económicas" and "Fecha de Apertura Oferta Económica" are equivalent and complmenetary, we will merge them and drop "Fecha de Apertura Oferta Económica" column.

# %%
df["Fecha de Apertura de Ofertas Económicas"] = df[
    "Fecha de Apertura de Ofertas Económicas"
].fillna(df["Fecha de Apertura Oferta Económica"])
df.drop("Fecha de Apertura Oferta Económica", axis=1, inplace=True)

print_null_count(df)
# Out:
# Fecha de Inicio Concesión              91
# Plazo Total de la Concesión            60
# Puesta en Servicio Provisoria (PSP)    91
# Inspector (a) Fiscal                   40
# Inicio Plazo Concesión                 38
# Plazo de Concesión                     69
# dtype: int64

# %% [markdown]
# #### Columns "Fecha de Inicio Concesión" and "Inicio Plazo Concesión" are equivalent and complmenetary, we will merge them and drop "Inicio Plazo Concesión" column.

# %%
df["Fecha de Inicio Concesión"] = df["Fecha de Inicio Concesión"].fillna(
    df["Inicio Plazo Concesión"]
)
df.drop("Inicio Plazo Concesión", axis=1, inplace=True)

print_null_count(df)
# Out:
# Plazo Total de la Concesión            60
# Puesta en Servicio Provisoria (PSP)    91
# Inspector (a) Fiscal                   40
# Plazo de Concesión                     69
# dtype: int64

# %% [markdown]
# #### Columns "Plazo Total de la Concesión" and "Plazo de Concesión" are equivalent and complmenetary, we will merge them and drop "Plazo de Concesión" column.

# %%
df["Plazo Total de la Concesión"] = df["Plazo Total de la Concesión"].fillna(
    df["Plazo de Concesión"]
)
df.drop("Plazo de Concesión", axis=1, inplace=True)

print_null_count(df)
# Out:
# Puesta en Servicio Provisoria (PSP)    91
# Inspector (a) Fiscal                   40
# dtype: int64

# %% [markdown]
# #### For columns "Puesta en Servicio Provisoria (PSP)" and "Inspector (a) Fiscal" the missed values are because they are not assigned yet, we will assignd "No Asignado" to them.

# %%
df["Puesta en Servicio Provisoria (PSP)"] = df[
    "Puesta en Servicio Provisoria (PSP)"
].fillna("No Asignado")
df["Inspector (a) Fiscal"] = df["Inspector (a) Fiscal"].fillna("No Asignado")

print_null_count(df)

df.reset_index(drop=True, inplace=True)

print(df.info())
# Out:
# Series([], dtype: int64)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   id                                       129 non-null    object
#  1   status                                   129 non-null    object
#  2   url                                      129 non-null    object
#  3   Tipo Iniciativa                          129 non-null    object
#  4   Región                                   129 non-null    object
#  5   Provincia                                129 non-null    object
#  6   Comuna                                   129 non-null    object
#  7   Volumen                                  129 non-null    object
#  8   Presupuesto Oficial                      129 non-null    object
#  9   *Valor de referencia                     129 non-null    object
#  10  Llamado a Licitación                     129 non-null    object
#  11  Fecha de Recepción de Ofertas Técnicas   129 non-null    object
#  12  Fecha de Apertura de Ofertas Económicas  129 non-null    object
#  13  Decreto de Adjudicación                  129 non-null    object
#  14  Sociedad Concesionaria                   129 non-null    object
#  15  Fecha de Inicio Concesión                129 non-null    object
#  16  Plazo Total de la Concesión              129 non-null    object
#  17  Puesta en Servicio Provisoria (PSP)      129 non-null    object
#  18  Inspector (a) Fiscal                     129 non-null    object
# dtypes: object(19)
# memory usage: 19.3+ KB
# None

# %% [markdown]
# ### 2.2 Normalize column names

# %%
df.rename(
    columns={
        "Tipo Iniciativa": "tipo iniciativa",
        "Región": "region",
        "Provincia": "provincia",
        "Comuna": "comuna",
        "Volumen": "volumen",
        "Presupuesto Oficial": "presupuesto oficial",
        "*Valor de referencia": "valor de referencia",
        "Llamado a Licitación": "llamado a licitacion",
        "Fecha de Recepción de Ofertas Técnicas": "recepcion ofertas tecnicas",
        "Fecha de Apertura de Ofertas Económicas": "apertura ofertas economicas",
        "Decreto de Adjudicación": "decreto adjudicacion",
        "Sociedad Concesionaria": "sociedad concesionaria",
        "Fecha de Inicio Concesión": "inicio concesion",
        "Plazo Total de la Concesión": "plazo concesion",
        "Puesta en Servicio Provisoria (PSP)": "psp",
        "Inspector (a) Fiscal": "inspector fiscal",
    },
    inplace=True,
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           129 non-null    object
#  1   status                       129 non-null    object
#  2   url                          129 non-null    object
#  3   tipo iniciativa              129 non-null    object
#  4   region                       129 non-null    object
#  5   provincia                    129 non-null    object
#  6   comuna                       129 non-null    object
#  7   volumen                      129 non-null    object
#  8   presupuesto oficial          129 non-null    object
#  9   valor de referencia          129 non-null    object
#  10  llamado a licitacion         129 non-null    object
#  11  recepcion ofertas tecnicas   129 non-null    object
#  12  apertura ofertas economicas  129 non-null    object
#  13  decreto adjudicacion         129 non-null    object
#  14  sociedad concesionaria       129 non-null    object
#  15  inicio concesion             129 non-null    object
#  16  plazo concesion              129 non-null    object
#  17  psp                          129 non-null    object
#  18  inspector fiscal             129 non-null    object
# dtypes: object(19)
# memory usage: 19.3+ KB

# %% [markdown]
# ### 2.3 Handling duplicate rows

# %% [markdown]
# #### Complete row analysis

# %%
df[df.duplicated(keep=False)].sort_values(by="id")
# Out:
#       id                      status  \
# 118  117  Construcción y Operación
# 108  117  Construcción y Operación
# 103  161  Construcción y Operación
# 113  161  Construcción y Operación
# 114  187  Construcción y Operación
# 106  187  Construcción y Operación
# 110  197  Construcción y Operación
# 121  197  Construcción y Operación
# 105  200  Construcción y Operación
# 115  200  Construcción y Operación
# 107  207  Construcción y Operación
# 116  207  Construcción y Operación
# 120  211  Construcción y Operación
# 109  211  Construcción y Operación
# 111  218  Construcción y Operación
# 102  218  Construcción y Operación
# 112  228  Construcción y Operación
# 104  228  Construcción y Operación
#
#                                                    url tipo iniciativa  \
# 118  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 108  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 103  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 113  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 114  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 106  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 110  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 121  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 105  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 115  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 107  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 116  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 120  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 109  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 111  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 102  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 112  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 104  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
#
#                                                 region  \
# 118                                      Metropolitana
# 108                                      Metropolitana
# 103                                         Valparaíso
# 113                                         Valparaíso
# 114                                           Coquimbo
# 106                                           Coquimbo
# 110                                 Arica y Parinacota
# 121                                 Arica y Parinacota
# 105                                      Maule y Ñuble
# 115                                      Maule y Ñuble
# 107                                           Coquimbo
# 116                                           Coquimbo
# 120  Magallanes y Aysén del General Carlos Ibáñez d...
# 109  Magallanes y Aysén del General Carlos Ibáñez d...
# 111                         Metropolitana y Valparaíso
# 102                         Metropolitana y Valparaíso
# 112                       Ñuble, Biobío y La Araucanía
# 104                       Ñuble, Biobío y La Araucanía
#
#                                         provincia  \
# 118                                      Santiago
# 108                                      Santiago
# 103                          Valparaíso, Quillota
# 113                          Valparaíso, Quillota
# 114                         Elqui, Choapa, Limarí
# 106                         Elqui, Choapa, Limarí
# 110                                         Arica
# 121                                         Arica
# 105           Talca, Linares, Punilla y Diguillín
# 115           Talca, Linares, Punilla y Diguillín
# 107                                         Elqui
# 116                                         Elqui
# 120                        Magallanes y Coyhaique
# 109                        Magallanes y Coyhaique
# 111  Santiago, San Antonio, Talagante y Melipilla
# 102  Santiago, San Antonio, Talagante y Melipilla
# 112                   Diguillín, Biobío y Malleco
# 104                   Diguillín, Biobío y Malleco
#
#                                                 comuna  \
# 118                                           Pudahuel
# 108                                           Pudahuel
# 103                     Puchuncaví, Quintero y Nogales
# 113                     Puchuncaví, Quintero y Nogales
# 114    La Serena, Coquimbo, Ovalle, Canela y Los Vilos
# 106    La Serena, Coquimbo, Ovalle, Canela y Los Vilos
# 110                                              Arica
# 121                                              Arica
# 105  Río Claro, San Rafael, Pelarco, Talca, Maule, ...
# 115  Río Claro, San Rafael, Pelarco, Talca, Maule, ...
# 107                                          La Serena
# 116                                          La Serena
# 120                           Punta Arenas y Coyhaique
# 109                           Punta Arenas y Coyhaique
# 111  Cartagena, Cerrillos, El Monte, Estación Centr...
# 102  Cartagena, Cerrillos, El Monte, Estación Centr...
# 112  Chillán Viejo, Bulnes, Pemuco, Cabrero, Los Án...
# 104  Chillán Viejo, Bulnes, Pemuco, Cabrero, Los Án...
#
#                                                volumen  \
# 118                                         379.000 m2
# 108                                         379.000 m2
# 103                              43 km aproximadamente
# 113                              43 km aproximadamente
# 114    244,5 km tramo interurbano y 16 km tramo urbano
# 106    244,5 km tramo interurbano y 16 km tramo urbano
# 110                        11.600 m2 (aproximadamente)
# 121                        11.600 m2 (aproximadamente)
# 105                                            195 kms
# 115                                            195 kms
# 107                                          13.550 m2
# 116                                          13.550 m2
# 120  16.014 m2 (Terminal actual Punta Arenas 6.471 ...
# 109  16.014 m2 (Terminal actual Punta Arenas 6.471 ...
# 111                                           132,8 km
# 102                                           132,8 km
# 112                                             169 km
# 104                                             169 km
#
#              presupuesto oficial  \
# 118   UF 14.980.000 (MM USD 700)
# 108   UF 14.980.000 (MM USD 700)
# 103    UF 5.250.000 (MM USD 220)
# 113    UF 5.250.000 (MM USD 220)
# 114                UF 12.155.000
# 106                UF 12.155.000
# 110  UF 2.031.000  (MM USD 83,1)
# 121  UF 2.031.000  (MM USD 83,1)
# 105   UF 19.180.000 (MM USD 785)
# 115   UF 19.180.000 (MM USD 785)
# 107     UF 1.415.000 (MM USD 59)
# 116     UF 1.415.000 (MM USD 59)
# 120  UF 3.965.000 (MM USD 162,2)
# 109  UF 3.965.000 (MM USD 162,2)
# 111   UF 21.287.000 (MM USD 892)
# 102   UF 21.287.000 (MM USD 892)
# 112      14.215.000 (MM USD 596)
# 104      14.215.000 (MM USD 596)
#
#                                    valor de referencia  \
# 118  La inversión en MM USD se calcula en base a la...
# 108  La inversión en MM USD se calcula en base a la...
# 103  La inversión en MM USD se calcula en base a la...
# 113  La inversión en MM USD se calcula en base a la...
# 114  La inversión en MM USD se calcula en base a la...
# 106  La inversión en MM USD se calcula en base a la...
# 110  La inversión en MM USD se calcula en base a la...
# 121  La inversión en MM USD se calcula en base a la...
# 105  La inversión en MM USD se calcula en base a la...
# 115  La inversión en MM USD se calcula en base a la...
# 107  La inversión en MM US$, se calcula a la Unidad...
# 116  La inversión en MM US$, se calcula a la Unidad...
# 120  La inversión en MM USD se calcula en base a la...
# 109  La inversión en MM USD se calcula en base a la...
# 111  Valor de referencia La inversión en MM US$, se...
# 102  Valor de referencia La inversión en MM US$, se...
# 112  La inversión en MM US$, se calcula a la Unidad...
# 104  La inversión en MM US$, se calcula a la Unidad...
#
#          llamado a licitacion recepcion ofertas tecnicas  \
# 118       20 de junio de 2014    30 de diciembre de 2014
# 108       20 de junio de 2014    30 de diciembre de 2014
# 103   27 de noviembre de 2015        29 de marzo de 2016
# 113   27 de noviembre de 2015        29 de marzo de 2016
# 114        12 de mayo de 2018    30 de noviembre de 2018
# 106        12 de mayo de 2018    30 de noviembre de 2018
# 110  21 de septiembre de 2018    21 de diciembre de 2018
# 121  21 de septiembre de 2018    21 de diciembre de 2018
# 105     19 de octubre de 2019      30 de octubre de 2020
# 115     19 de octubre de 2019      30 de octubre de 2020
# 107   27 de noviembre de 2019        29 de enero de 2021
# 116   27 de noviembre de 2019        29 de enero de 2021
# 120      17 de agosto de 2019    20 de noviembre de 2020
# 109      17 de agosto de 2019    20 de noviembre de 2020
# 111        6 de marzo de 2021      29 de octubre de 2021
# 102        6 de marzo de 2021      29 de octubre de 2021
# 112     29 de octubre de 2021   23 de septiembre de 2022
# 104     29 de octubre de 2021   23 de septiembre de 2022
#
#     apertura ofertas economicas  \
# 118         20 de junio de 2014
# 108         20 de junio de 2014
# 103         22 de abril de 2016
# 113         22 de abril de 2016
# 114     26 de diciembre de 2018
# 106     26 de diciembre de 2018
# 110            16 de enero 2019
# 121            16 de enero 2019
# 105     27 de noviembre de 2020
# 115     27 de noviembre de 2020
# 107          5 de marzo de 2021
# 116          5 de marzo de 2021
# 120     22 de diciembre de 2020
# 109     22 de diciembre de 2020
# 111     26 de noviembre de 2021
# 102     26 de noviembre de 2021
# 112       21 de octubre de 2022
# 104       21 de octubre de 2022
#
#                                   decreto adjudicacion  \
# 118                     N° 105 del 12 de marzo de 2015
# 108                     N° 105 del 12 de marzo de 2015
# 103                      N° 199 del 7 de junio de 2016
# 113                      N° 199 del 7 de junio de 2016
# 114  Decreto Nº 47 del 30 de abril de 2019 (DO 28.1...
# 106  Decreto Nº 47 del 30 de abril de 2019 (DO 28.1...
# 110  Nº 11 del 4 de febrero de 2019 (publicado en e...
# 121  Nº 11 del 4 de febrero de 2019 (publicado en e...
# 105                       N° 5 del 13 de marzo de 2021
# 115                       N° 5 del 13 de marzo de 2021
# 107                      N° 79 del 30 de abril de 2021
# 116                      N° 79 del 30 de abril de 2021
# 120                       N° 8 del 22 de marzo de 2021
# 109                       N° 8 del 22 de marzo de 2021
# 111                      N° 10 del 13 de enero de 2022
# 102                      N° 10 del 13 de enero de 2022
# 112  Nº 214 del 4 de diciembre de 2022 (publicado e...
# 104  Nº 214 del 4 de diciembre de 2022 (publicado e...
#
#                                 sociedad concesionaria       inicio concesion  \
# 118         Sociedad Concesionaria Nuevo Pudahuel S.A.   1 de octubre de 2015
# 108         Sociedad Concesionaria Nuevo Pudahuel S.A.   1 de octubre de 2015
# 103  Sociedad Concesionaria Nuevo Camino Nogales - ...   23 de agosto de 2016
# 113  Sociedad Concesionaria Nuevo Camino Nogales - ...   23 de agosto de 2016
# 114         Sociedad Concesionaria Ruta del Elqui S.A.  28 de octubre de 2019
# 106         Sociedad Concesionaria Ruta del Elqui S.A.  28 de octubre de 2019
# 110    Sociedad Concesionaria Aeropuerto de Arica S.A.    20 de marzo de 2019
# 121    Sociedad Concesionaria Aeropuerto de Arica S.A.    20 de marzo de 2019
# 105    Sociedad Concesionaria Survías Maule-Ñuble S.A.    13 de marzo de 2021
# 115    Sociedad Concesionaria Survías Maule-Ñuble S.A.    13 de marzo de 2021
# 107                     Consorcio Aeropuerto IV Región   11 de agosto de 2021
# 116                     Consorcio Aeropuerto IV Región   11 de agosto de 2021
# 120  Red Aeroportuaria Austral Sociedad Concesionar...    22 de marzo de 2021
# 109  Red Aeroportuaria Austral Sociedad Concesionar...    22 de marzo de 2021
# 111  Sociedad Concesionaria San Antonio - Santiago ...    22 de marzo de 2022
# 102  Sociedad Concesionaria San Antonio - Santiago ...    22 de marzo de 2022
# 112
# 104
#
#                                 plazo concesion psp  \
# 118                          Plazo fijo 20 años
# 108                          Plazo fijo 20 años
# 103  Plazo variable, máximo 38 años (456 meses)
# 113  Plazo variable, máximo 38 años (456 meses)
# 114  Plazo variable, máximo 30 años (360 meses)
# 106  Plazo variable, máximo 30 años (360 meses)
# 110                          Plazo fijo 15 años
# 121                          Plazo fijo 15 años
# 105  Plazo variable, máximo 32 años (384 meses)
# 115  Plazo variable, máximo 32 años (384 meses)
# 107  260 meses o VPI &gt;= 0,8 x ITC + 36 meses
# 116  260 meses o VPI &gt;= 0,8 x ITC + 36 meses
# 120  Plazo variable, máximo 32 años (384 meses)
# 109  Plazo variable, máximo 32 años (384 meses)
# 111             32 años máximo (plazo variable)
# 102             32 años máximo (plazo variable)
# 112            Plazo variable máximo de 30 años
# 104            Plazo variable máximo de 30 años
#
#                                       inspector fiscal
# 118                       Juan Carlos Figueroa Quezada
# 108                       Juan Carlos Figueroa Quezada
# 103                             Claudio Asenjo Schultz
# 113                             Claudio Asenjo Schultz
# 114  Jaime Yáñez Urzúa (construcción) / Max Schrade...
# 106  Jaime Yáñez Urzúa (construcción) / Max Schrade...
# 110                                   Fernanda Ardiles
# 121                                   Fernanda Ardiles
# 105                             Ricardo Oyarzo Cárcamo
# 115                             Ricardo Oyarzo Cárcamo
# 107                                        Jaime Yáñez
# 116                                        Jaime Yáñez
# 120                          Juan Carlos Parada Aliste
# 109                          Juan Carlos Parada Aliste
# 111                                    Nicole Albornoz
# 102                                    Nicole Albornoz
# 112  Lester Poblete (construcción) / Arturo Parada ...
# 104  Lester Poblete (construcción) / Arturo Parada ...

# %% [markdown]
# ##### There are 9 duplicate rows, we will drop them.

# %%
df.drop_duplicates(keep="first", inplace=True)
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           120 non-null    object
#  1   status                       120 non-null    object
#  2   url                          120 non-null    object
#  3   tipo iniciativa              120 non-null    object
#  4   region                       120 non-null    object
#  5   provincia                    120 non-null    object
#  6   comuna                       120 non-null    object
#  7   volumen                      120 non-null    object
#  8   presupuesto oficial          120 non-null    object
#  9   valor de referencia          120 non-null    object
#  10  llamado a licitacion         120 non-null    object
#  11  recepcion ofertas tecnicas   120 non-null    object
#  12  apertura ofertas economicas  120 non-null    object
#  13  decreto adjudicacion         120 non-null    object
#  14  sociedad concesionaria       120 non-null    object
#  15  inicio concesion             120 non-null    object
#  16  plazo concesion              120 non-null    object
#  17  psp                          120 non-null    object
#  18  inspector fiscal             120 non-null    object
# dtypes: object(19)
# memory usage: 17.9+ KB

# %% [markdown]
# #### id column analysis

# %%
df.duplicated(["id"], keep=False).sum()

df[df.duplicated(["id"], keep=False)].sort_values(by=["id", "status"])
# Out:
#       id                      status  \
# 118  117               Adjudicación
# 108  117  Construcción y Operación
# 115  161               Adjudicación
# 103  161  Construcción y Operación
# 112  187               Adjudicación
# 106  187  Construcción y Operación
# 117  197               Adjudicación
# 110  197  Construcción y Operación
# 113  200               Adjudicación
# 105  200  Construcción y Operación
# 111  207               Adjudicación
# 107  207  Construcción y Operación
# 119  211               Adjudicación
# 109  211  Construcción y Operación
# 116  218               Adjudicación
# 102  218  Construcción y Operación
# 114  228               Adjudicación
# 104  228  Construcción y Operación
#
#                                                    url tipo iniciativa  \
# 118  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 108  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 115  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 103  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 112  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 106  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 117  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 110  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 113  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 105  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 111  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 107  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 119  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 109  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 116  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 102  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 114  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
# 104  https://concesiones.mop.gob.cl/proyectos/Pagin...         Pública
#
#                                                 region  \
# 118                                      Metropolitana
# 108                                      Metropolitana
# 115                                         Valparaíso
# 103                                         Valparaíso
# 112                                           Coquimbo
# 106                                           Coquimbo
# 117                                 Arica y Parinacota
# 110                                 Arica y Parinacota
# 113                                      Maule y Ñuble
# 105                                      Maule y Ñuble
# 111                                           Coquimbo
# 107                                           Coquimbo
# 119  Magallanes y Aysén del General Carlos Ibáñez d...
# 109  Magallanes y Aysén del General Carlos Ibáñez d...
# 116                         Metropolitana y Valparaíso
# 102                         Metropolitana y Valparaíso
# 114                       Ñuble, Biobío y La Araucanía
# 104                       Ñuble, Biobío y La Araucanía
#
#                                         provincia  \
# 118                                      Santiago
# 108                                      Santiago
# 115                          Valparaíso, Quillota
# 103                          Valparaíso, Quillota
# 112                         Elqui, Choapa, Limarí
# 106                         Elqui, Choapa, Limarí
# 117                                         Arica
# 110                                         Arica
# 113           Talca, Linares, Punilla y Diguillín
# 105           Talca, Linares, Punilla y Diguillín
# 111                                         Elqui
# 107                                         Elqui
# 119                        Magallanes y Coyhaique
# 109                        Magallanes y Coyhaique
# 116  Santiago, San Antonio, Talagante y Melipilla
# 102  Santiago, San Antonio, Talagante y Melipilla
# 114                   Diguillín, Biobío y Malleco
# 104                   Diguillín, Biobío y Malleco
#
#                                                 comuna  \
# 118                                           Pudahuel
# 108                                           Pudahuel
# 115                     Puchuncaví, Quintero y Nogales
# 103                     Puchuncaví, Quintero y Nogales
# 112    La Serena, Coquimbo, Ovalle, Canela y Los Vilos
# 106    La Serena, Coquimbo, Ovalle, Canela y Los Vilos
# 117                                              Arica
# 110                                              Arica
# 113  Río Claro, San Rafael, Pelarco, Talca, Maule, ...
# 105  Río Claro, San Rafael, Pelarco, Talca, Maule, ...
# 111                                          La Serena
# 107                                          La Serena
# 119                           Punta Arenas y Coyhaique
# 109                           Punta Arenas y Coyhaique
# 116  Cartagena, Cerrillos, El Monte, Estación Centr...
# 102  Cartagena, Cerrillos, El Monte, Estación Centr...
# 114  Chillán Viejo, Bulnes, Pemuco, Cabrero, Los Án...
# 104  Chillán Viejo, Bulnes, Pemuco, Cabrero, Los Án...
#
#                                                volumen  \
# 118                                         379.000 m2
# 108                                         379.000 m2
# 115                              43 km aproximadamente
# 103                              43 km aproximadamente
# 112    244,5 km tramo interurbano y 16 km tramo urbano
# 106    244,5 km tramo interurbano y 16 km tramo urbano
# 117                        11.600 m2 (aproximadamente)
# 110                        11.600 m2 (aproximadamente)
# 113                                            195 kms
# 105                                            195 kms
# 111                                          13.550 m2
# 107                                          13.550 m2
# 119  16.014 m2 (Terminal actual Punta Arenas 6.471 ...
# 109  16.014 m2 (Terminal actual Punta Arenas 6.471 ...
# 116                                           132,8 km
# 102                                           132,8 km
# 114                                             169 km
# 104                                             169 km
#
#              presupuesto oficial  \
# 118   UF 14.980.000 (MM USD 700)
# 108   UF 14.980.000 (MM USD 700)
# 115    UF 5.250.000 (MM USD 220)
# 103    UF 5.250.000 (MM USD 220)
# 112                UF 12.155.000
# 106                UF 12.155.000
# 117  UF 2.031.000  (MM USD 83,1)
# 110  UF 2.031.000  (MM USD 83,1)
# 113   UF 19.180.000 (MM USD 785)
# 105   UF 19.180.000 (MM USD 785)
# 111     UF 1.415.000 (MM USD 59)
# 107     UF 1.415.000 (MM USD 59)
# 119  UF 3.965.000 (MM USD 162,2)
# 109  UF 3.965.000 (MM USD 162,2)
# 116   UF 21.287.000 (MM USD 892)
# 102   UF 21.287.000 (MM USD 892)
# 114      14.215.000 (MM USD 596)
# 104      14.215.000 (MM USD 596)
#
#                                    valor de referencia  \
# 118  La inversión en MM USD se calcula en base a la...
# 108  La inversión en MM USD se calcula en base a la...
# 115  La inversión en MM USD se calcula en base a la...
# 103  La inversión en MM USD se calcula en base a la...
# 112  La inversión en MM USD se calcula en base a la...
# 106  La inversión en MM USD se calcula en base a la...
# 117  La inversión en MM USD se calcula en base a la...
# 110  La inversión en MM USD se calcula en base a la...
# 113  La inversión en MM USD se calcula en base a la...
# 105  La inversión en MM USD se calcula en base a la...
# 111  La inversión en MM US$, se calcula a la Unidad...
# 107  La inversión en MM US$, se calcula a la Unidad...
# 119  La inversión en MM USD se calcula en base a la...
# 109  La inversión en MM USD se calcula en base a la...
# 116  Valor de referencia La inversión en MM US$, se...
# 102  Valor de referencia La inversión en MM US$, se...
# 114  La inversión en MM US$, se calcula a la Unidad...
# 104  La inversión en MM US$, se calcula a la Unidad...
#
#          llamado a licitacion recepcion ofertas tecnicas  \
# 118       20 de junio de 2014    30 de diciembre de 2014
# 108       20 de junio de 2014    30 de diciembre de 2014
# 115   27 de noviembre de 2015        29 de marzo de 2016
# 103   27 de noviembre de 2015        29 de marzo de 2016
# 112        12 de mayo de 2018    30 de noviembre de 2018
# 106        12 de mayo de 2018    30 de noviembre de 2018
# 117  21 de septiembre de 2018    21 de diciembre de 2018
# 110  21 de septiembre de 2018    21 de diciembre de 2018
# 113     19 de octubre de 2019      30 de octubre de 2020
# 105     19 de octubre de 2019      30 de octubre de 2020
# 111   27 de noviembre de 2019        29 de enero de 2021
# 107   27 de noviembre de 2019        29 de enero de 2021
# 119      17 de agosto de 2019    20 de noviembre de 2020
# 109      17 de agosto de 2019    20 de noviembre de 2020
# 116        6 de marzo de 2021      29 de octubre de 2021
# 102        6 de marzo de 2021      29 de octubre de 2021
# 114     29 de octubre de 2021   23 de septiembre de 2022
# 104     29 de octubre de 2021   23 de septiembre de 2022
#
#     apertura ofertas economicas  \
# 118         20 de junio de 2014
# 108         20 de junio de 2014
# 115         22 de abril de 2016
# 103         22 de abril de 2016
# 112     26 de diciembre de 2018
# 106     26 de diciembre de 2018
# 117            16 de enero 2019
# 110            16 de enero 2019
# 113     27 de noviembre de 2020
# 105     27 de noviembre de 2020
# 111          5 de marzo de 2021
# 107          5 de marzo de 2021
# 119     22 de diciembre de 2020
# 109     22 de diciembre de 2020
# 116     26 de noviembre de 2021
# 102     26 de noviembre de 2021
# 114       21 de octubre de 2022
# 104       21 de octubre de 2022
#
#                                   decreto adjudicacion  \
# 118                     N° 105 del 12 de marzo de 2015
# 108                     N° 105 del 12 de marzo de 2015
# 115                      N° 199 del 7 de junio de 2016
# 103                      N° 199 del 7 de junio de 2016
# 112  Decreto Nº 47 del 30 de abril de 2019 (DO 28.1...
# 106  Decreto Nº 47 del 30 de abril de 2019 (DO 28.1...
# 117  Nº 11 del 4 de febrero de 2019 (publicado en e...
# 110  Nº 11 del 4 de febrero de 2019 (publicado en e...
# 113                       N° 5 del 13 de marzo de 2021
# 105                       N° 5 del 13 de marzo de 2021
# 111                      N° 79 del 30 de abril de 2021
# 107                      N° 79 del 30 de abril de 2021
# 119                       N° 8 del 22 de marzo de 2021
# 109                       N° 8 del 22 de marzo de 2021
# 116                      N° 10 del 13 de enero de 2022
# 102                      N° 10 del 13 de enero de 2022
# 114  Nº 214 del 4 de diciembre de 2022 (publicado e...
# 104  Nº 214 del 4 de diciembre de 2022 (publicado e...
#
#                                 sociedad concesionaria       inicio concesion  \
# 118         Sociedad Concesionaria Nuevo Pudahuel S.A.   1 de octubre de 2015
# 108         Sociedad Concesionaria Nuevo Pudahuel S.A.   1 de octubre de 2015
# 115  Sociedad Concesionaria Nuevo Camino Nogales - ...   23 de agosto de 2016
# 103  Sociedad Concesionaria Nuevo Camino Nogales - ...   23 de agosto de 2016
# 112         Sociedad Concesionaria Ruta del Elqui S.A.  28 de octubre de 2019
# 106         Sociedad Concesionaria Ruta del Elqui S.A.  28 de octubre de 2019
# 117    Sociedad Concesionaria Aeropuerto de Arica S.A.    20 de marzo de 2019
# 110    Sociedad Concesionaria Aeropuerto de Arica S.A.    20 de marzo de 2019
# 113    Sociedad Concesionaria Survías Maule-Ñuble S.A.    13 de marzo de 2021
# 105    Sociedad Concesionaria Survías Maule-Ñuble S.A.    13 de marzo de 2021
# 111                     Consorcio Aeropuerto IV Región   11 de agosto de 2021
# 107                     Consorcio Aeropuerto IV Región   11 de agosto de 2021
# 119  Red Aeroportuaria Austral Sociedad Concesionar...    22 de marzo de 2021
# 109  Red Aeroportuaria Austral Sociedad Concesionar...    22 de marzo de 2021
# 116  Sociedad Concesionaria San Antonio - Santiago ...    22 de marzo de 2022
# 102  Sociedad Concesionaria San Antonio - Santiago ...    22 de marzo de 2022
# 114
# 104
#
#                                 plazo concesion          psp  \
# 118                          Plazo fijo 20 años  No Asignado
# 108                          Plazo fijo 20 años
# 115  Plazo variable, máximo 38 años (456 meses)  No Asignado
# 103  Plazo variable, máximo 38 años (456 meses)
# 112  Plazo variable, máximo 30 años (360 meses)  No Asignado
# 106  Plazo variable, máximo 30 años (360 meses)
# 117                          Plazo fijo 15 años  No Asignado
# 110                          Plazo fijo 15 años
# 113  Plazo variable, máximo 32 años (384 meses)  No Asignado
# 105  Plazo variable, máximo 32 años (384 meses)
# 111  260 meses o VPI &gt;= 0,8 x ITC + 36 meses  No Asignado
# 107  260 meses o VPI &gt;= 0,8 x ITC + 36 meses
# 119  Plazo variable, máximo 32 años (384 meses)  No Asignado
# 109  Plazo variable, máximo 32 años (384 meses)
# 116             32 años máximo (plazo variable)  No Asignado
# 102             32 años máximo (plazo variable)
# 114            Plazo variable máximo de 30 años  No Asignado
# 104            Plazo variable máximo de 30 años
#
#                                       inspector fiscal
# 118                                        No Asignado
# 108                       Juan Carlos Figueroa Quezada
# 115                                        No Asignado
# 103                             Claudio Asenjo Schultz
# 112                                        No Asignado
# 106  Jaime Yáñez Urzúa (construcción) / Max Schrade...
# 117                                        No Asignado
# 110                                   Fernanda Ardiles
# 113                                        No Asignado
# 105                             Ricardo Oyarzo Cárcamo
# 111                                        No Asignado
# 107                                        Jaime Yáñez
# 119                                        No Asignado
# 109                          Juan Carlos Parada Aliste
# 116                                        No Asignado
# 102                                    Nicole Albornoz
# 114                                        No Asignado
# 104  Lester Poblete (construcción) / Arturo Parada ...

# %% [markdown]
# ##### There are 9 duplicate rows, we will drop them where status is "Adjudicación"

# %%
# There are 9 duplicate rows, we will drop them where status is "Adjudicación"
df = (
    df.sort_values(["id", "status"])
    .drop_duplicates(["id"], keep="last")
    .reset_index(drop=True)
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           111 non-null    object
#  1   status                       111 non-null    object
#  2   url                          111 non-null    object
#  3   tipo iniciativa              111 non-null    object
#  4   region                       111 non-null    object
#  5   provincia                    111 non-null    object
#  6   comuna                       111 non-null    object
#  7   volumen                      111 non-null    object
#  8   presupuesto oficial          111 non-null    object
#  9   valor de referencia          111 non-null    object
#  10  llamado a licitacion         111 non-null    object
#  11  recepcion ofertas tecnicas   111 non-null    object
#  12  apertura ofertas economicas  111 non-null    object
#  13  decreto adjudicacion         111 non-null    object
#  14  sociedad concesionaria       111 non-null    object
#  15  inicio concesion             111 non-null    object
#  16  plazo concesion              111 non-null    object
#  17  psp                          111 non-null    object
#  18  inspector fiscal             111 non-null    object
# dtypes: object(19)
# memory usage: 16.6+ KB

# %% [markdown]
# ### 2.4 Transforming data by column.

# %% [markdown]
# #### Column "status"

# %% [markdown]
# #### Column "tipo iniciativa"

# %%
df["status"].value_counts()
df["status"] = df["status"].astype(str)
df["status"] = df["status"].apply(lambda x: unidecode(x.lower()))

df.replace({"status": "adjudicacion"}, "1-adjudicacion", inplace=True)
df.replace({"status": "construccion"}, "2-construccion", inplace=True)
df.replace({"status": "operacion"}, "3-operacion", inplace=True)
df.replace(
    {"status": "construccion y operacion"}, "4-construccion y operacion", inplace=True
)
df.replace({"status": "finalizada"}, "5-finalizada", inplace=True)
df["status"].value_counts()
# Out:
# status
# 3-operacion                   51
# 5-finalizada                  31
# 2-construccion                20
# 4-construccion y operacion     9
# Name: count, dtype: int64

# %% [markdown]
# #### Column "tipo iniciativa"

# %%
df["tipo iniciativa"].value_counts()
df.replace({"tipo iniciativa": "Iniciativa Pública"}, "Pública", inplace=True)
df.replace({"tipo iniciativa": ""}, "No definido", inplace=True)
df["tipo iniciativa"].value_counts()
# Out:
# tipo iniciativa
# Pública        77
# Privada        26
# No definido     8
# Name: count, dtype: int64

# %% [markdown]
# #### Column "region"

# %%
def get_region_number(x):
    for i in x:
        if i.find("arica") != -1:
            x[x.index(i)] = str(15)
        elif i.find("tarapaca") != -1:
            x[x.index(i)] = str(1)
        elif i.find("antofagasta") != -1:
            x[x.index(i)] = str(2)
        elif i.find("atacama") != -1:
            x[x.index(i)] = str(3)
        elif i.find("coquimbo") != -1:
            x[x.index(i)] = str(4)
        elif i.find("valparaiso") != -1:
            x[x.index(i)] = str(5)
        elif i.find("metropolitana") != -1:
            x[x.index(i)] = str(13)
        elif i.find("o'higgins") != -1:
            x[x.index(i)] = str(6)
        elif i.find("maule") != -1:
            x[x.index(i)] = str(7)
        elif i.find("biobio") != -1:
            x[x.index(i)] = str(8)
        elif i.find("araucania") != -1:
            x[x.index(i)] = str(9)
        elif i.find("lagos") != -1:
            x[x.index(i)] = str(10)
        elif i.find("rios") != -1:
            x[x.index(i)] = str(14)
        elif i.find("aysen") != -1:
            x[x.index(i)] = str(11)
        elif i.find("magallanes") != -1:
            x[x.index(i)] = str(12)
        elif i.find("nuble") != -1:
            x[x.index(i)] = str(16)
    return x


def extract_region_data(x):
    x = x.lower()
    x = unidecode(x)
    x = x.replace("arica y parinacota", "arica_y_parinacota")
    x = x.replace("es y an", "es_y_an")
    print(x)
    x = re.split(",| y ", x)
    x = [i.strip() for i in x]
    x = get_region_number(x)
    x.sort(key=int)
    return ",".join(x)

# %%
df["region"] = df["region"].apply(lambda x: extract_region_data(x))
df["region"].value_counts()
# Out:
# metropolitana
# metropolitana
# coquimbo
# metropolitana
# libertador general bernardo o'higgins
# antofagasta
# metropolitana
# region metropolitana
# la araucania
# antofagasta y biobio
# region de tarapaca
# tarapaca
# magallanes
# los lagos
# coquimbo
# biobio
# region de tarapaca
# metropolitana
# biobio
# tarapaca
# los lagos
# valparaiso
# valparaiso
# nuble
# los lagos
# metropolitana
# biobio
# valparaiso, metropolitana y libertador general bernardo o'higgins
# antofagasta
# metropolitana
# coquimbo
# region metropolitana
# metropolitana
# valparaiso
# arica_y_parinacota
# metropolitana y valparaiso
# maule y nuble
# metropolitana
# coquimbo
# region metropolitana
# biobio
# magallanes y aysen del general carlos ibanez del campo
# del maule
# biobio
# metropolitana
# metropolitana
# metropolitana y valparaiso
# coquimbo
# valparaiso
# los rios y los lagos
# coquimbo
# metropolitana
# libertador general bernardo o'higgins
# nuble, biobio y la araucania
# valparaiso y metropolitana
# antofagasta
# metropolitana
# valparaiso y metropolitana
# valparaiso
# biobio
# region del maule
# valparaiso
# region metropolitana
# nuble, biobio y la araucania
# atacama
# la araucania
# coquimbo
# metropolitana, valparaiso y coquimbo
# maule y nuble
# araucania y los rios
# los rios y los lagos
# metropolitana, general libertador bernardo o'higgins y maule
# coquimbo y atacama
# antofagasta
# los lagos
# antofagasta
# metropolitana
# antofagasta
# biobio y la araucania
# metropolitana
# valparaiso
# valparaiso
# tarapaca
# biobio
# metropolitana
# biobio
# metropolitana
# metropolitana
# metropolitana
# metropolitana
# metropolitana
# metropolitana
# coquimbo
# atacama
# region de magallanes_y_antartica chilena
# biobio
# antofagasta
# antofagasta
# los lagos
# arica_y_parinacota
# tarapaca, coquimbo y libertador general bernando o'higgins
# metropolitana, los rios y los lagos
# metropolitana
# metropolitana
# valparaiso
# metropolitana
# antofagasta
# region metropolitana
# region metropolitana
# metropolitana
# metropolitana
# region
# 13          33
# 2            9
# 8            9
# 5            9
# 4            8
# 1            5
# 10           5
# 5,13         4
# 9            2
# 12           2
# 15           2
# 6            2
# 8,9,16       2
# 10,14        2
# 7,16         2
# 7            2
# 3            2
# 2,8          1
# 16           1
# 5,6,13       1
# 11,12        1
# 4,5,13       1
# 9,14         1
# 6,7,13       1
# 3,4          1
# 8,9          1
# 1,4,6        1
# 10,13,14     1
# Name: count, dtype: int64

# %% [markdown]
# #### Column "provincia"

# %%
def extract_provincia_data(x):
    x = x.lower()
    x = unidecode(x)
    print(x)
    x = re.split(",| y ", x)
    x = [i.strip() for i in x]
    x.sort()
    return ",".join(x)

# %%
df["provincia"].value_counts()
df["provincia"] = df["provincia"].apply(lambda x: extract_provincia_data(x))
df["provincia"].value_counts()
# Out:
# santiago
# santiago
# elqui
# santiago
# colchagua y cardenal caro
# antofagasta
# santiago
# santiago
# cautin
# antofagasta y concepcion
# iquique
# iquique
# magallanes
# llanquihue
# limari y elqui
# concepcion
# iquique
# santiago
# concepcion
# iquique
# llanquihue
# valparaiso, quillota
# petorca y quillota
# punilla
# llanquihue
# santiago
# nuble y concepcion
# san antonio y cachapoal
# antofagasta y el loa
# santiago
# elqui, choapa, limari
# santiago
# santiago
# petorca
# arica
# santiago, san antonio, talagante y melipilla
# talca, linares, punilla y diguillin
# santiago
# elqui
# santiago
# biobio y concepcion
# magallanes y coyhaique
# cauquenes, linares y talca
# biobio y concepcion
# maipo
# maipo y melipilla
# santiago, san antonio, talagante y melipilla
# coquimbo
# valparaiso y quillota
# valdivia, ranco y llanquihue
# coquimbo
# santiago
# cachapoal y cardenal caro
# diguillin, biobio y malleco
# santiago, chacabuco y los andes
# el loa
# santiago
# santiago, marga marga, melipilla y valparaiso
# san antonio y valparaiso
# concepcion
# talca
# petorca y quillota
# melipilla
# nuble, biobio y malleco
# huasco y copiapo
# malleco y cautin
# choapa, limari y elqui
# santiago, chacabuco, san felipe, quillota, petorca y choapa
# talca, linares, nuble
# cautin, valdivia y ranco
# ranco, osorno y llanquihue
# santiago, cordillera, cachapoal, colchagua y curico
# huasco y elqui
# el loa
# llanquihue
# antofagasta
# santiago
# antofagasta y el loa
# biobio y malleco
# santiago
# los andes
# san felipe, quillota, marga marga, los andes y valparaiso
# tamarugal y iquique
# concepcion, biobio y nuble
# santiago
# concepcion y arauco
# santiago
# santiago y maipo
# santiago
# santiago
# santiago y chachabuco
# santiago
# elqui
# copiapo
# magallanes
# concepcion
# antofagasta
# el loa
# llanquihue
# arica
# iquique, elqui, cachapoal
# santiago, valdivia y llanquihue
# santiago
# santiago
# los andes
# santiago
# antofagasta y el loa
# santiago
# santiago
# santiago
# santiago
# provincia
# santiago                                                 28
# llanquihue                                                5
# iquique                                                   4
# concepcion                                                4
# elqui                                                     3
# antofagasta,el loa                                        3
# antofagasta                                               3
# el loa                                                    3
# magallanes                                                2
# biobio,concepcion                                         2
# melipilla,san antonio,santiago,talagante                  2
# arica                                                     2
# quillota,valparaiso                                       2
# choapa,elqui,limari                                       2
# los andes                                                 2
# coquimbo                                                  2
# petorca,quillota                                          2
# cachapoal,san antonio                                     1
# concepcion,nuble                                          1
# punilla                                                   1
# elqui,limari                                              1
# petorca                                                   1
# antofagasta,concepcion                                    1
# cardenal caro,colchagua                                   1
# cautin                                                    1
# cauquenes,linares,talca                                   1
# coyhaique,magallanes                                      1
# diguillin,linares,punilla,talca                           1
# maipo,melipilla                                           1
# llanquihue,ranco,valdivia                                 1
# cachapoal,cardenal caro                                   1
# biobio,diguillin,malleco                                  1
# maipo                                                     1
# marga marga,melipilla,santiago,valparaiso                 1
# san antonio,valparaiso                                    1
# talca                                                     1
# melipilla                                                 1
# biobio,malleco,nuble                                      1
# copiapo,huasco                                            1
# cautin,malleco                                            1
# chacabuco,los andes,santiago                              1
# chacabuco,choapa,petorca,quillota,san felipe,santiago     1
# linares,nuble,talca                                       1
# llanquihue,osorno,ranco                                   1
# cautin,ranco,valdivia                                     1
# cachapoal,colchagua,cordillera,curico,santiago            1
# elqui,huasco                                              1
# biobio,malleco                                            1
# los andes,marga marga,quillota,san felipe,valparaiso      1
# iquique,tamarugal                                         1
# biobio,concepcion,nuble                                   1
# arauco,concepcion                                         1
# maipo,santiago                                            1
# chachabuco,santiago                                       1
# copiapo                                                   1
# cachapoal,elqui,iquique                                   1
# llanquihue,santiago,valdivia                              1
# Name: count, dtype: int64

# %% [markdown]
# #### Column "comuna"

# %%
df["comuna"].value_counts()
df["comuna"] = df["comuna"].apply(lambda x: extract_provincia_data(x))
df["comuna"].value_counts()
# Out:
# maipu y la florida
# cerillos, cerro navia, conchali, estacion central, independencia, la cisterna, la florida, la pintana, la reina, lo barnechea, lo prado, nunoa, penalolen, puente alto, recoleta, renca, san bernardo, san miguel, santiago y vitacura
# la serena
# pudahuel
# nancagua, chepica, santa cruz, palmilla, peralillo, marchigue, lolol y chimbarongo
# antofagasta
# providencia
# cerro navia
# temuco
# antofagasta y concepcion
# iquique
# iquique
# punta arenas
# puerto montt
# coquimbo y ovalle
# san pedro de la paz y hualpen
# iquique
# huechuraba, vitacura, las condes y providencia
# talcahuano
# iquique
# puerto montt
# puchuncavi, quintero y nogales
# zapallar y nogales
# coihueco y san fabian
# puerto montt
# la reina, nunoa, penalolen y macul
# chillan, chillan viejo, ranquil, florida, tome y penco
# malloa, san vicente de tagua tagua, peumo, las cabras, san pedro, santo domingo y san antonio
# sierra gorda y calama
# maipu y pudahuel
# la serena, coquimbo, ovalle, canela y los vilos
# pudahuel
# lo barnechea
# petorca
# arica
# cartagena, cerrillos, el monte, maipu, melipilla, pedro aguirre cerda, padre hurtado, penaflor, santiago, san antonio y talagante
# rio claro, san rafael, pelarco, talca, maule, san javier, villa alegre, yerbas buenas, linares, longavi, retiro, parral, niquen, san carlos, san nicolas, chillan y chillan viejo
# pudahuel
# la serena
# quinta normal
# san pedro de la paz, concepcion, santa juana, nacimiento y coihue
# punta arenas y coyhaique
# cauquenes, parral y constitucion
# santa barbara, nacimiento, coronel y lota
# buin y paine
# san bernardo, calera de tango y penaflor
# cartagena, cerrillos, el monte, estacion central, maipu, melipilla, pedro aguirre cerda, padre hurtado, penaflor, santiago, san antonio, santo domingo y talagante
# coquimbo
# puchuncavi, quintero, nogales
# la union, rio bueno, los lagos y puerto varas
# la serena
# independencia
# rengo y pichilemu
# chillan viejo, bulnes, pemuco, cabrero, los angeles, mulchen, collipulli y ercilla
# quilicura, huechuraba, colina, rinconada, los andes y calle larga
# calama
# providencia
# maipu, pudahuel, curacavi casablanca, valparaiso, quilpue y villa alemana
# san antonio, cartagena, el tabo, el quisco, agarrobo y casablanca
# penco, talcahuano y concepcion
# talca
# zapallar y nogales
# melipilla
# chillan viejo, bulnes, cabrero, los angeles, mulchen, pemuco, yumbel y collipulli
# vallenar, copiapo y caldera
# collipulli, ercilla, victoria, vilcun, temuco, padre de las casas, freire, pitrufquen y gorbea
# los vilos, canela y coquimbo
# quilicura, colina, lampa, til- til, llay - llay, hijuelas, la calera, nogales, zapallar, la ligua, papudo y los vilos
# rio claro, san rafael, talca, maule, san javier, villa alegre, linares, longavi, retiro, parral, ninquen, san carlos, san nicolas, chillan, chillan viejo
# gorbea, loncoche, lanco, san jose de la mariquina, mafil, los lagos, paillaco, la union y rio bueno
# la union, rio bueno, san pablo, osorno, rio negro, purranque, frutillar, llanquihue, puerto varas y puerto montt
# la pintana, la granja, puente alto, san bernardo, buin, paine, rancagua, san fernando y curico
# vallenar, la serena y la higuera
# calama
# puerto montt, calbuco, maullin
# antofagasta
# las condes, vitacura, la reina, recoleta y huechuraba
# sierra gorda, calama y antofagasta
# los angeles, negrete, angol y renaico
# pudahuel
# los andes
# catemu, hijuelas, la calera, la cruz, limache, llay llay, los andes, panquehue, quillota, san esteban, san felipe, santa maria y villa alemana
# pozo almonte, iquique y alto hospicio
# concepcion, florida, cabrero, yumbel y yungay
# cerro navia, conchali, huechuraba, maipu, pudahul, quilicura, recoleta y renca
# coronel, lota, arauco, curanilahue y los alamos
# cerrillos, la cisterna, la florida, la granja, lo espejo, macul, maipu, penalolen y san ramon
# conchali, estacion central, cerrillos, independencia, el bosque, la cisterna, lo espejo, san miguel, pedro aguirre cerda, quilicura, quinta normal, renca, san bernardo, santiago y buin
# recoleta, independencia, santiago, vitacura, las condes y providencia
# huechuraba, providencia, las condes y vitacura
# vitacura, huechuraba, colina y lampa
# pudahuel
# la serena
# copiapo
# punta arenas
# talcahuano
# antofagasta
# calama
# puerto montt
# arica
# iquique, la serena, rancagua
# santiago, valdivia y puerto montt
# santiago
# santiago
# los andes
# santiago
# antofagasta, calama y mejillones
# cerrillos, estacion central
# estacion central, santiago, providencia, nunoa, puente alto, recoleta, las condes, lo prado, la reina, la granja, san ramon, macul, penalolen, la florida, renca, independencia, conchali, san joaquin, san miguel, quinta normal, maipu, pudahuel
# la cisterna
# santiago, san ramon, la granja, san miguel y san joaquin
# comuna
# pudahuel                                                                                                                                                                                                                         5
# la serena                                                                                                                                                                                                                        4
# puerto montt                                                                                                                                                                                                                     4
# iquique                                                                                                                                                                                                                          4
# antofagasta                                                                                                                                                                                                                      3
#                                                                                                                                                                                                                                 ..
# antofagasta,calama,mejillones                                                                                                                                                                                                    1
# cerrillos,estacion central                                                                                                                                                                                                       1
# conchali,estacion central,independencia,la florida,la granja,la reina,las condes,lo prado,macul,maipu,nunoa,penalolen,providencia,pudahuel,puente alto,quinta normal,recoleta,renca,san joaquin,san miguel,san ramon,santiago    1
# la cisterna                                                                                                                                                                                                                      1
# la granja,san joaquin,san miguel,san ramon,santiago                                                                                                                                                                              1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# #### Column "volumen"

# %%
print(df["volumen"].value_counts())
# Out:
# volumen
#              15
# 9 km          2
# 136 kms       2
# 5,2 km        2
# 3 kms         2
#              ..
# 116 m2        1
# 201 kms       1
# 42.166 m2     1
# 56.390 m2     1
# 14,68 km      1
# Name: count, Length: 93, dtype: int64

# %% [markdown]
# ## 3. Exporting the data

# %%
df.to_json("../data/mop_details_clean.json", orient="records")
